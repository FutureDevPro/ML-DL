# %%
import torch
import torch.nn as nn

layer = nn.Linear(3,2)

x = torch.tensor([[1.0,2.0,3.0]])

y = layer(x)
print(y)
# Out:
# tensor([[ 2.0214, -0.2734]], grad_fn=<AddmmBackward0>)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.Linear = nn.Linear(1,1)
    def forward(self,x):
        return self.Linear(x)
    
x = torch.tensor([[1.],[2.],[3.],[4.]])
y = torch.tensor([[2.],[4.],[6.],[8.]])

#Model
model = MyModel()

#loss & Optimizer
loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(),lr=0.1)

#training loop
for epoch in range(10):
    optimizer.zero_grad()
    y_pred = model(x)
    loss = loss_fn(y_pred , y)
    loss.backward()
    optimizer.step()

    print(f"Epoch {epoch + 1}, Loss: {loss.item():.4f}")

torch.save(model.state_dict(), "Linear_model.pth")
# Out:
# Epoch 1, Loss: 18.3568
# Epoch 2, Loss: 15.3983
# Epoch 3, Loss: 12.7186
# Epoch 4, Loss: 10.3212
# Epoch 5, Loss: 8.2078
# Epoch 6, Loss: 6.3774
# Epoch 7, Loss: 4.8262
# Epoch 8, Loss: 3.5465
# Epoch 9, Loss: 2.5271
# Epoch 10, Loss: 1.7522
